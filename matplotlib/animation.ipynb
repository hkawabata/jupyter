# %%
# %matplotlib inline
# %matplotlib nbagg
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

"""
fig = plt.figure()
ims = []

N = 100
x = np.arange(N) / N * np.pi * 2
for i in range(100):
    im = plt.plot(x, np.sin(x + np.pi*i/N), c='red')
    ims.append(im)
ani = animation.ArtistAnimation(fig, ims, interval=10)
plt.show()
"""

def func():
    fig = plt.figure()
    ims = []

    N = 100
    x = np.arange(N) / N * np.pi * 2
    for i in range(100):
        im = plt.plot(x, np.sin(x + np.pi*i/N), c='red')
        ims.append(im)
    
    return fig, ims
    #ani = animation.ArtistAnimation(fig, ims, interval=10)
    #plt.show()

f, i = func()
ani = animation.ArtistAnimation(f, i, interval=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
